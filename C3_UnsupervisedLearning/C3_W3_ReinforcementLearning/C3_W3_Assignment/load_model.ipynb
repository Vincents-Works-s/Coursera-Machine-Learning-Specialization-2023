# %%
import gym
import tensorflow as tf
import utils
import logging
logging.getLogger().setLevel(logging.ERROR)
# Out:
# Warning: Gym version v0.24.0 has a number of critical issues with `gym.make` such that the `reset` and `step` functions are called before returning the environment. It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1
# 2023-01-07 21:42:44.924341: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
env = gym.make('LunarLander-v2')
env.reset()
# Out:
# /Users/vincentruan/opt/anaconda3/envs/buddy/lib/python3.9/site-packages/Box2D/Box2D.py:19: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# array([-0.00152378,  1.4030244 , -0.1543511 , -0.3509188 ,  0.0017724 ,
#         0.03496278,  0.        ,  0.        ], dtype=float32)

# %%
model = tf.keras.models.load_model('lunar_lander_model.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2023-01-07 21:42:52.189997: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
filename = "./videos/lunar_lander.mp4"

utils.create_video(filename, env, model)
utils.embed_mp4(filename)
# Out:
# [swscaler @ 0x7f8039500000] Warning: data is not aligned! This can lead to a speed loss
#     <video width="840" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>
